# %% [markdown]
# # Trabalho 1 - PDI

# %% [markdown]
# ### Bibliotecas

# %%
from PIL import Image
import os
from matplotlib.pyplot import imshow, imsave, clf
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ### Funções

# %%
def open_image(path):
    filename, file_extension = os.path.splitext(path)

    im = Image.open(path)
    
#     if file_extension == '.png':
#         im = np.dot(im, 255)
        
    return im



def rgb_to_yiq(im):
    
    yiq_To_rgb = np.array([ [ +0.299,      +0.587,      +0.114],
                            [ +0.59590059, -0.27455667, -0.32134392],
                            [ +0.21153661, -0.52273617, +0.31119955]])
        
    img_yiq = np.dot(im, yiq_To_rgb.T)
    
    return img_yiq



def yiq_to_rgb(im_yiq):
    
    rgb_To_yiq = np.array([ [ +1.0, +0.9563, +0.6210],
                            [ +1.0, -0.2721, -0.6474],
                            [ +1.0, -1.1070, +1.7046]])
    

    img_rgb = np.dot(im_yiq, rgb_To_yiq.T)
    img_rgb = img_rgb.astype(int)
    img_rgb  = np.clip(img_rgb , a_min = 0, a_max = 255) 

    return img_rgb

def plot_channels(im, channels, negative=False, label=""):
    
    figure, plots = plt.subplots(ncols=3, nrows=1)

    for i, subplot in zip(range(3), plots):
        temp = np.zeros(im.shape, dtype='uint8')    
        temp[:,:,i] = im[:,:,i] if not negative else (255 - im[:,:,i])
        subplot.imshow(temp)
        imsave('imgs/' + label + channels[i] + '.png', temp)
        subplot.set_axis_off()
    plt.show()
    
    
def plot_negative_by_channels(im, channels, channel):

    temp = np.zeros(im.shape, dtype='uint8')    
    temp = im.copy()
    temp[:,:,channel] = 255 - temp[:,:,channel]
    
    clf()
    imshow(temp)
    imsave('imgs/' + 'negative_by_channel_' + channels[channel] + '.png', temp)
    
def addShine(im, shine, channels, channel='none'):

    temp = np.zeros(im.shape, dtype='uint8')    

    if channel == 'none': 
        temp = np.dot(im,shine)
        label = ''
    else: 
        print(im[1][6])
        print(im[1][7])

        temp = im.copy()
        
        temp[:,:,channel] = min(255, np.multiply(temp[:,:,channel],shine))
        
        print(temp[1][6])
        print(temp[1][7])
        label = channels[channel]

#         temp = im.copy()
#         print(im[:,:,channel])
#         im[:,:,channel] = (im[:,:,channel] / (1/shine)).copy()   #np.dot(temp[:,:,channel], shine)
        
#         print(im[:,:,channel])
        
    temp  = np.clip(temp , a_min = 0, a_max = 255)
    clf()
    imshow(temp)
    imsave('imgs/' + 'shine_' + str(shine) + '_' + label + '.png', temp)

# %% [markdown]
# ### Parametrização

# %%
img_path = 'ImagensTeste/lena256color.jpg'
channels = ['R', 'G', 'B']

# %% [markdown]
# ### Código

# %%
im = open_image(img_path)
imshow(im)

# %% [markdown]
# #### Conversão RGB -> YIQ -> RGB

# %%
#Convertendo de rgb para yiq 

img_yiq = rgb_to_yiq(im)
imshow(img_yiq)
imsave('imgs/' + 'YIQ' + '.png', img_yiq)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#Convertendo de yiq para rgb

img_rgb = yiq_to_rgb(img_yiq)    
imshow(img_rgb)
imsave('imgs/' + 'RGB' + '.png', img_rgb)

# %% [markdown]
# #### Separando canais RGB

# %%
#Separar imagem em três canais (R, G e B)

im = open_image(img_path)
im = np.array(im, dtype='int')

plot_channels(im, channels)

# %% [markdown]
# #### Negativo

# %%
im = open_image(img_path)
im = np.array(im, dtype='uint8')

im_negative = 255 - im
imshow(im_negative)
imsave('imgs/' + 'negative_image' + '.png', im_negative)

plot_channels(im, channels, negative=True, label='negative')

# %%
plot_negative_by_channels(im, channels, channel=0)

# %%
plot_negative_by_channels(im, channels, channel=1)

# %%
plot_negative_by_channels(im, channels, channel=2)

# %%
#Negativando canal Y

img_yiq = rgb_to_yiq(im)
img_yiq[:,:,0] = 255 - img_yiq[:,:,0]
img_rgb = yiq_to_rgb(img_yiq)    
                
imshow(img_rgb)
imsave('imgs/' + 'negativeY' + '.png', img_rgb)

# %% [markdown]
# #### Controle de brilho multiplicativo

# %%
# Brilho Multiplicativo
# Pixel_resultante = Pixel_atual * C

im = open_image(img_path)
im = np.array(im, dtype='uint8')

shine = 2

addShine(im, shine, channels)

# %%
addShine(im, shine, channels, channel=0)
# Out:
# [206 153 103]
# [203 150  96]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-489-18aa1f89dca0> in <module>
# ----> 1 addShine(im, shine, channels, channel=0)
#
# <ipython-input-488-7a1acd0730c2> in addShine(im, shine, channels, channel)
#      72         temp = im.copy()
#      73
# ---> 74         temp[:,:,channel] = min(255, temp[:,:,channel]*shine)
#      75
#      76         print(temp[1][6])
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
addShine(im, shine, channels, channel=1)
# Out:
# [206 153 103]
# [203 150  96]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-481-c91c031b577a> in <module>
# ----> 1 addShine(im, shine, channels, channel=1)
#
# <ipython-input-480-ca5fc9948e12> in addShine(im, shine, channels, channel)
#      72         temp = im.copy()
#      73
# ---> 74         temp[:,:,channel] = min(255, np.multiply(temp[:,:,channel],shine))
#      75
#      76         print(temp[1][6])
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
addShine(im, shine, channels, channel=2)
# Out:
# [[[206 156 121]
#   [206 156 119]
#   [209 157 120]
#   ...
#   [215 157 119]
#   [217 161 126]
#   [186 132  96]]
#
#  [[210 157 123]
#   [209 157 120]
#   [209 157 118]
#   ...
#   [247 193 157]
#   [239 186 152]
#   [176 126  93]]
#
#  [[211 157 121]
#   [209 155 117]
#   [208 155 115]
#   ...
#   [225 176 146]
#   [204 157 129]
#   [144  99  70]]
#
#  ...
#
#  [[ 22  18   6]
#   [ 29  25  14]
#   [ 34  27  19]
#   ...
#   [ 94  55  38]
#   [111  68  52]
#   [119  73  58]]
#
#  [[ 14  12   0]
#   [ 21  17   6]
#   [ 27  20  12]
#   ...
#   [105  63  47]
#   [118  72  57]
#   [118  71  55]]
#
#  [[ 13  11   0]
#   [ 19  17   5]
#   [ 28  21  13]
#   ...
#   [125  82  66]
#   [134  87  71]
#   [132  83  68]]]
# [[[206 156   0]
#   [206 156   0]
#   [209 157   0]
#   ...
#   [215 157   0]
#   [217 161   0]
#   [186 132   0]]
#
#  [[210 157   0]
#   [209 157   0]
#   [209 157   0]
#   ...
#   [247 193   0]
#   [239 186   0]
#   [176 126   0]]
#
#  [[211 157   0]
#   [209 155   0]
#   [208 155   0]
#   ...
#   [225 176   0]
#   [204 157   0]
#   [144  99   0]]
#
#  ...
#
#  [[ 22  18   0]
#   [ 29  25   0]
#   [ 34  27   0]
#   ...
#   [ 94  55   0]
#   [111  68   0]
#   [119  73   0]]
#
#  [[ 14  12   0]
#   [ 21  17   0]
#   [ 27  20   0]
#   ...
#   [105  63   0]
#   [118  72   0]
#   [118  71   0]]
#
#  [[ 13  11   0]
#   [ 19  17   0]
#   [ 28  21   0]
#   ...
#   [125  82   0]
#   [134  87   0]
#   [132  83   0]]]
